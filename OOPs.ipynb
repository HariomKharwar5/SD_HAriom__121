# %% [markdown]
# <a href="https://colab.research.google.com/github/HariomKharwar5/SD_HAriom__121/blob/main/OOPs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class skills:
  def welcome_msg(self):
    print("Welcome to skill")

# %%
rohan = skills()
rohan.welcome_msg()
# Out:
# Welcome to skill

# %%
print(type(rohan))
# Out:
# <class '__main__.skills'>

# %%
class skills1 :
  def __init__(self,phone_number,email_id,student_id):
    self.phone_number = phone_number
    self.email_id = email_id
    self.student_id = student_id

  def return_student_details(self):
    return self.student_id,self.phone_number,self.email_id

# %%
rohan = skills1(8081609898,"hariomkumarkharwar@gmail.com",101)

# %%
rohan.phone_number
# Out:
# 8081609898

# %%
rohan.email_id
# Out:
# 'hariomkumarkharwar@gmail.com'

# %%
rohan.student_id
# Out:
# 101

# %%
sudha =skills1(9891609898,"sudhakumarikharwar@gmail.com",102)

# %%
sudha.phone_number
# Out:
# 9891609898

# %%
sudha.email_id
# Out:
# 'sudhakumarikharwar@gmail.com'

# %%
sudha.student_id
# Out:
# 102

# %%
#Project On Expense Tracker

stored_password = "hari123"
stored_Name = "Hariom"
expenses = [
    {"Category": "Food", "Amount": 500},
    {"Category": "Travel", "Amount": 1200},
    {"Category": "Shopping", "Amount": 800},
    {"Category": "Electricity Bill", "Amount": 1500}
]

password = input("Enter Password: ")

if password == stored_password:
    print("\nLogin Successful!")
    print("Welcome", stored_Name)

    print("\nYour Expenses:")

    total = 0
    for expense in expenses:
        print(f"{expense['Category']} : ₹{expense['Amount']}")
        total += expense['Amount']

    print("-----------------------")
    print("Total Expense = ₹", total)

else:
    print("Wrong Password!")
# Out:
# Enter Password: hari123
#
# Login Successful!
# Welcome Hariom
#
# Your Expenses:
# Food : ₹500
# Travel : ₹1200
# Shopping : ₹800
# Electricity Bill : ₹1500
# -----------------------
# Total Expense = ₹ 4000

# %%
users = {
    "Hariom": {
        "password": "hari123",
        "expenses": {
            "Food": 500,
            "Travel": 1200,
            "Shopping": 800
        }
    },
    "Aman": {
        "password": "aman456",
        "expenses": {
            "Food": 300,
            "Movie": 600,
            "Petrol": 900
        }
    }
}

username = input("Enter Username: ")
password = input("Enter Password: ")

if username in users and users[username]["password"] == password:
    print("Login Successful!")

    total = 0
    print("\nExpenses:")
    for category, amount in users[username]["expenses"].items():
        print(f"{category}: ₹{amount}")
        total += amount

    print("Total Expense:", total)

else:
    print("Wrong Username or Password")
# Out:
# Enter Username: Hariom
# Enter Password: hari123
# Login Successful!
#
# Expenses:
# Food: ₹500
# Travel: ₹1200
# Shopping: ₹800
# Total Expense: 2500
