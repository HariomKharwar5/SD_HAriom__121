# %% [markdown]
# <a href="https://colab.research.google.com/github/HariomKharwar5/SD_HAriom__121/blob/main/TupleSetList.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l = [1,2,3,45,5]
l1 = []
for i in l :
  l1.append(i**2)

# %%
print(l1)
# Out:
# [1, 4, 9, 2025, 25]

# %%
[i**2 for i in l]
# Out:
# [1, 4, 9, 2025, 25]

# %%
d = {"keys1" :1,"keys2" :2,"keys" :3,"keys" :4}

# %%
{k:v**2 for k,v in d.items()}
# Out:
# {'keys1': 1, 'keys2': 4, 'keys': 16}

# %%
d.items()
# Out:
# dict_items([('keys1', 1), ('keys2', 2), ('keys', 4)])

# %%
num = 123
text = str(num)

print(text)
print(type(text))
# Out:
# 123
# <class 'str'>

# %%
my_tuple = (1, 2, 3, 4)
my_list = list(my_tuple)
print(my_list)
print(type(my_list))
# Out:
# [1, 2, 3, 4]
# <class 'list'>

# %%
set={2,3,4,5,5,4,3,2,1}

# %%
print(set)
# Out:
# {1, 2, 3, 4, 5}
